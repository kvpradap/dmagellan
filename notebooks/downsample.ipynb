# %%
import cython

# %%
# %load_ext cython

# %% [markdown]
# Downsample steps
# 1. create inverted index
# 2. take sample
# 3. probe inverted index

# %% [markdown]
# #### Create inverted index

# %% [markdown]
# Read file

# %%
import py_entitymatching as em
A = em.load_dataset('person_table_A')

# %%
A.columns
# Out:
# Index([u'ID', u'name', u'birth_year', u'hourly_wage', u'address', u'zipcode'], dtype='object')

# %%
# %%cython -a
# def get_str_indices(A):
#     x = []
#     cdef int i = 0
#     for t in A.dtypes:
#         if t == 'object':
#             x.append(i)
#         i += 1
#     return x
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.25.2 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_87e39522b50698d9d6e21a9f071ef3d2.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# ...

# %%
# %%cython -a
# from libcpp.string import string
# from libcpp.vector import vector
# class StringContainer:
#     cdef vector[string] v
#
#     def __cinit__(self, string_values):
#         self.v = string_values

# %%
get_str_indices(A)
# Out:
# [0, 1, 4]

# %%
A.values
# Out:
# array([['a1', 'Kevin Smith', 1989, 30.0, '607 From St, San Francisco',
#         94107],
#        ['a2', 'Michael Franklin', 1988, 27.5,
#         '1652 Stockton St, San Francisco', 94122],
#        ['a3', 'William Bridge', 1986, 32.0,
#         '3131 Webster St, San Francisco', 94107],
#        ['a4', 'Binto George', 1987, 32.5, '423 Powell St, San Francisco',
#         94122],
#        ['a5', 'Alphonse Kemper', 1984, 35.0,
#         '1702 Post Street, San Francisco', 94122]], dtype=object)

# %%
# %%cython -a
# # distutils: language = c++
# from libcpp.vector cimport vector
# from libcpp.string cimport string
# from libcpp.set cimport set as oset
# from libcpp.map cimport map as omap
#
# cdef class VectorStack:
#     cdef vector[int] v
#
#     def push(self, int x):
#         self.v.push_back(x)
#
#     def pop(self):
#         if self.v.empty():
#             raise IndexError()
#         x = self.v.back()
#         self.v.pop_back()
#         return x
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.25.2 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_62956093fa62a1f1174c6373dba32894.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# ...

# %%
# %%cython -a
# #distutils: language=c++
# from cython.parallel cimport prange
# from libcpp.string cimport string as ostring
# from libcpp.map cimport map as omap
# cimport numpy as np
#
# cdef ostring concat(values):
#     cdef ostring s
#     cdef int i
#     for i in xrange(len(values)):
#         s = s + ' ' + values[i]
#     return s
#
# cdef int _temp(np.ndarray A):
#     cdef int n = A.shape[0]
#     cdef int i, j
#     cdef int k = 0
#     cdef ostring l
#     for i in xrange(n):
#         k += i
#     return k
#
# def build_inverted_index(A, )
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.25.2 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_e51ff87b11cc78f33298aef6b3dca91a.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# ...
