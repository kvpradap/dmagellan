# %%
import sys
sys.path.append('/Users/pradap/Documents/Research/Python-Package/scaling/dmagellan/')
import pandas as pd

# %%
# imports
from dmagellan.blocker.attrequivalence.attr_equiv_blocker import AttrEquivalenceBlocker
from dmagellan.blocker.overlap.overlapblocker_ddf import OverlapBlocker
from dmagellan.blocker.blackbox.blackbox_blocker import BlackBoxBlocker
from dmagellan.blocker.rulebased.rule_based_blocker import RuleBasedBlocker
from dmagellan.feature.autofeaturegen import get_features_for_blocking
from dmagellan.feature.extractfeatures import extract_feature_vecs
from dmagellan.feature.autofeaturegen import get_features_for_matching
from dmagellan.matcher.dtmatcher import DTMatcher
from dmagellan.utils.py_utils.utils import concat_df
from dask import delayed
from dask.threaded import get
from distributed import Client
import py_entitymatching as em
# Out:
# /Users/pradap/miniconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
client = Client('127.0.0.1:8786')

# %%
from dask import dataframe as dd

# %%
orig_A = dd.read_csv('./data/citeseer_nonans.csv', usecols=['id', 'title'])
orig_B = dd.read_csv('./data/dblp_nonans.csv', usecols=['id', 'title'])

# %%
A = dd.read_csv('./data/sample_citeseer.csv', usecols=['id', 'title'], blocksize=400000)
B = dd.read_csv('./data/sample_dblp.csv', usecols=['id', 'title'], blocksize=400000)

# %%
orig_A.npartitions, orig_B.npartitions
# Out:
# (4, 5)

# %%
# help(dd.read_csv)

# %%
len(A)
# Out:
# 10000

# %%
# blocking
ob = OverlapBlocker()
C = ob.block_tables(A, B, 'id', 'id', 'title', 'title', 
                    overlap_size=4, nltable_chunks=A.npartitions, nrtable_chunks=B.npartitions, 
                    scheduler=get, compute=False, 
                    rem_stop_words=True
                   )
# len(C)

# %%
type(C)
# Out:
# dask.delayed.Delayed

# %%
C.visualize()

# %%
from dask.dataframe import from_delayed
from dask.distributed import progress
m = pd.DataFrame([{'_id':0, 'l_id' : 1, 'r_id' : 2}])
D = from_delayed(C, meta=m)

# %%
res = D.compute(get=get)

# %%
res
# Out:
#      _id     l_id     r_id
# 0      0  1540813  2301803
# 1      1  1204705  1963198
# 2      2  1662738  1357308
# 3      3  1610568  1752493
# 4      4   127115   167524
# 5      5   237687   167524
# 6      6   911863   167524
# 7      7  1144429   167524
# 8      8  1787877   167524
# 9      9   917313    58767
# 10    10   237687   218368
# 11    11   911863   218368
# 12    12  1787877   218368
# 13    13   246692  1146666
# 14    14   237687  1315997
# 15    15   345194  1315997
# 16    16   911863  1315997
# 17    17  1787877  1315997
# 18    18   352066  1589393
# 19    19   250607  1491955
# 20    20  1407517  1491955
# 21    21   579160  1287350
# 22    22  1407517  2062412
# 23    23   246692   736918
# 24    24   638454  2424271
# 25    25  1125464   169440
# 26    26   614056  1127906
# 27    27    63721  2364931
# 28    28  1144429  2364931
# 29    29  1206130  1291359
# ..   ...      ...      ...
# 706  706  1089559   485897
# 707  707   781781   561071
# 708  708   374226   509707
# 709  709   366302  1318630
# 710  710   529555  1318630
# 711  711   361537  1474710
# 712  712  1348987   715343
# 713  713  1417288  1343109
# 714  714   755829  1244915
# 715  715  1399411  2413540
# 716  716  1547390  2413540
# 717  717   395753  1661252
# 718  718   771442  1661252
# 719  719   161142  1717851
# 720  720   598021   340062
# 721  721   667618  1630809
# 722  722   366302  2345336
# 723  723   374226  2345336
# 724  724   529555  2345336
# 725  725   374226  2186940
# 726  726   679746   765058
# 727  727  1811674   210789
# 728  728   141569   212685
# 729  729   781781   212685
# 730  730   286571  2402471
# 731  731   565763  2402471
# 732  732  1417288  2402471
# 733  733   851938  1510800
# 734  734   936465   167163
# 735  735   515821  2185935
#
# [736 rows x 3 columns]
# distributed.client - WARNING - Client report stream closed to scheduler

# %%
# client.cancel(E)
from dask.distributed import progress

progress(E)
# Out:
# tornado.application - ERROR - Exception in callback <functools.partial object at 0x112cdf9f0>
# Traceback (most recent call last):
#   File "/Users/pradap/miniconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 604, in _run_callback
#     ret = callback()
#   File "/Users/pradap/miniconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/pradap/miniconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 619, in <lambda>
#     self.add_future(ret, lambda f: f.result())
#   File "/Users/pradap/miniconda2/lib/python2.7/site-packages/tornado/concurrent.py", line 237, in result
#     raise_exc_info(self._exc_info)
#   File "/Users/pradap/miniconda2/lib/python2.7/site-packages/tornado/gen.py", line 1024, in run
#     yielded = self.gen.send(value)
#   File "/Users/pradap/miniconda2/lib/python2.7/site-packages/distributed/diagnostics/progressbar.py", line 198, in listen
#     self._draw_stop(**response)
#   File "/Users/pradap/miniconda2/lib/python2.7/site-packages/distributed/diagnostics/progressbar.py", line 266, in _draw_stop
#     self.elapsed_time.value = '<div style="padding: 0px 10px 5px 10px"><b>Finished:</b> ' + format_time(self.elapsed) + '</div>'
# AttributeError: 'MultiProgressWidget' object has no attribute 'elapsed_time'

# %%
x = list(range(0, len(E), len(E)//3))

# %%
x.append(len(E))

# %%
t = E.index.values

# %%
t1 = t.compute()

# %%
t1[0]
# Out:
# 0

# %%
E1 = E.compute()

# %%
E.npartitions
# Out:
# 1

# %%
C.
# Out:
# (None, None, None, None, None)

# %%
from dask.dataframe.utils import assert_eq, assert_dask_graph, make_meta
dsk = {('x', 0): pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]},
                                  index=[0, 1, 3]),
           ('x', 1): pd.DataFrame({'a': [4, 5, 6], 'b': [3, 2, 1]},
                                  index=[5, 6, 8]),
           ('x', 2): pd.DataFrame({'a': [7, 8, 9], 'b': [0, 0, 0]},
                                  index=[9, 9, 9])}
meta = make_meta({'a': 'i8', 'b': 'i8'}, index=pd.Index([], 'i8'))
ddf1 = dd.DataFrame(dsk, 'x', meta, [0, 4,  9])

# %%
E1 = E.set_index('_id')

# %%
x[-1] = 4139

# %%
E1.divisions
# Out:
# (0, 4139)

# %%
E2 = E1.repartition(x)

# %%
ddf1.compute()
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 3  3  6
# 5  4  3
# 6  5  2
# 8  6  1

# %%
F = D1.persist(get=client.get)

# %%
F.npartitions
# Out:
# 1

# %%
m = pd.DataFrame(d)

# %%
m = pd.DataFrame([{'_id' : 0, 'l_id' : 1, 'r_id' : 2}])
D = from_delayed(C, meta=m)

# %%
type(D)
# Out:
# dask.dataframe.core.DataFrame

# %%
client.cancel(E)
E = D.persist(get=client.get)
progress(E)

# %%
from dask.distributed import progress

# %%
x = list(range(0, len(E), 1035))

# %%
x
# Out:
# [0, 1035, 2070, 3105]

# %%
help(E.repartition)
# Out:
# Help on method repartition in module dask.dataframe.core:
#
# repartition(self, divisions=None, npartitions=None, freq=None, force=False) method of dask.dataframe.core.DataFrame instance
#     Repartition dataframe along new divisions
#
#     Parameters
#     ----------
#     divisions : list, optional
#         List of partitions to be used. If specified npartitions will be
#         ignored.
#     npartitions : int, optional
#         Number of partitions of output, must be less than npartitions of
#         input. Only used if divisions isn't specified.
#     freq : str, pd.Timedelta
#         A period on which to partition timeseries data like ``'7D'`` or
#         ``'12h'`` or ``pd.Timedelta(hours=12)``.  Assumes a datetime index.
#     force : bool, default False
#         Allows the expansion of the existing divisions.
#         If False then the new divisions lower and upper bounds must be
#         the same as the old divisions.
#
#     Examples
#     --------
#     >>> df = df.repartition(npartitions=10)  # doctest: +SKIP
#     >>> df = df.repartition(divisions=[0, 5, 10, 20])  # doctest: +SKIP
#     >>> df = df.repartition(freq='7d')  # doctest: +SKIP

# %%
F = E.repartition(divisions=[0, 10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-2f0cbbef86d3> in <module>()
# ----> 1 F = E.repartition(divisions=[0, 10])
#
# /Users/pradap/miniconda2/lib/python2.7/site-packages/dask/dataframe/core.pyc in repartition(self, divisions, npartitions, freq, force)
#     887             return repartition_npartitions(self, npartitions)
#     888         elif divisions is not None:
# --> 889             return repartition(self, divisions, force=force)
#     890         elif freq is not None:
#     891             return repartition_freq(self, freq=freq)
#
# /Users/pradap/miniconda2/lib/python2.7/site-packages/dask/dataframe/core.pyc in repartition(df, divisions, force)
#    3733         out = 'repartition-merge-' + token
#    3734         dsk = repartition_divisions(df.divisions, divisions,
# -> 3735                                     df._name, tmp, out, force=force)
#    3736         return new_dd_object(merge(df.dask, dsk), out,
#    3737                              df._meta, divisions)
#
# /Users/pradap/miniconda2/lib/python2.7/site-packages/dask/dataframe/core.pyc in repartition_divisions(a, b, name, out1, out2, force)
#    3529         if a[0] != b[0]:
#    3530             msg = 'left side of old and new divisions are different'
# -> 3531             raise ValueError(msg)
#    3532         if a[-1] != b[-1]:
#    3533             msg = 'right side of old and new divisions are different'
#
# ValueError: left side of old and new divisions are different

# %%
type(E)
# Out:
# dask.dataframe.core.DataFrame

# %%
client.cancel(E)

# %%
client.has_what()
# Out:
# {'tcp://127.0.0.1:51066': [],
#  'tcp://127.0.0.1:51067': [],
#  'tcp://127.0.0.1:51068': []}

# %%
client = Client('127.0.0.1:8786')

# %%
D = C.compute(get=client.get, optimize_graph=False)

# %%
len(D)
# Out:
# 357

# %%
L = pd.read_csv('./data/sample_labeled_data.csv')
L = L[['_id', 'l_id', 'r_id', 'label']]

# %%
F = get_features_for_matching(orig_A.compute(), orig_B.compute())

# %%
F
# Out:
#                       feature_name left_attribute right_attribute  \
# 0                        id_id_exm             id              id
# 1                        id_id_anm             id              id
# 2                   id_id_lev_dist             id              id
# 3                    id_id_lev_sim             id              id
# 4      title_title_jac_qgm_3_qgm_3          title           title
# 5  title_title_cos_dlm_dc0_dlm_dc0          title           title
# 6                  title_title_mel          title           title
# 7             title_title_lev_dist          title           title
# 8              title_title_lev_sim          title           title
#
#   left_attr_tokenizer right_attr_tokenizer  simfunction  \
# 0                None                 None  exact_match
# 1                None                 None     abs_norm
# 2                None                 None     lev_dist
# 3                None                 None      lev_sim
# 4               qgm_3                qgm_3      jaccard
# 5             dlm_dc0              dlm_dc0       cosine
# 6                None                 None  monge_elkan
# 7                None                 None     lev_dist
# 8                None                 None      lev_sim
#
#                                                     function  \
# 0                        <function id_id_exm at 0x133eb66e0>
# 1                        <function id_id_anm at 0x177575cf8>
# 2                   <function id_id_lev_dist at 0x177575de8>
# 3                    <function id_id_lev_sim at 0x177575c08>
# 4      <function title_title_jac_qgm_3_qgm_3 at 0x177575b90>
# 5  <function title_title_cos_dlm_dc0_dlm_dc0 at 0x177575b18>
# 6                  <function title_title_mel at 0x177575aa0>
# 7             <function title_title_lev_dist at 0x177575a28>
# 8              <function title_title_lev_sim at 0x1775759b0>
#
#                                                                                        function_source  \
# 0  from dmagellan.feature.simfunctions import *\nfrom dmagellan.feature.tokenizers import *\ndef id...
# 1  from dmagellan.feature.simfunctions import *\nfrom dmagellan.feature.tokenizers import *\ndef id...
# 2  from dmagellan.feature.simfunctions import *\nfrom dmagellan.feature.tokenizers import *\ndef id...
# 3  from dmagellan.feature.simfunctions import *\nfrom dmagellan.feature.tokenizers import *\ndef id...
# 4  from dmagellan.feature.simfunctions import *\nfrom dmagellan.feature.tokenizers import *\ndef ti...
# 5  from dmagellan.feature.simfunctions import *\nfrom dmagellan.feature.tokenizers import *\ndef ti...
# 6  from dmagellan.feature.simfunctions import *\nfrom dmagellan.feature.tokenizers import *\ndef ti...
# 7  from dmagellan.feature.simfunctions import *\nfrom dmagellan.feature.tokenizers import *\ndef ti...
# 8  from dmagellan.feature.simfunctions import *\nfrom dmagellan.feature.tokenizers import *\ndef ti...
#
#    is_auto_generated
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True

# %%
# help(extract_feature_vecs)

# %%
L.head()
# Out:
#    _id     l_id     r_id  label
# 0    0   401372  1446376      0
# 1    1  1349544    12210      1
# 2    2  1328193  1921746      1
# 3    3   824620  1311578      0
# 4    4  1100045   535453      0

# %%
# Convert L into feature vectors using updated F
H = extract_feature_vecs(L, orig_A, orig_B, 
                         '_id', 'l_id', 'r_id', 'id', 'id', 
                          feature_table=F, 
                          attrs_after='label', nchunks=4,
                          show_progress=True, compute=True, 
                         scheduler=client.get)

# %%
# client.restart()

# %%
H.head()
# Out:
#    _id     l_id     r_id  id_id_exm  id_id_anm  id_id_lev_dist  id_id_lev_sim  \
# 0    0   401372  1446376          0   0.277502               4       0.428571
# 1    1  1349544    12210          0   0.009048               6       0.142857
# 2    2  1328193  1921746          0   0.691139               5       0.285714
# 3    3   824620  1311578          0   0.628724               7       0.000000
# 4    4  1100045   535453          0   0.486756               6       0.142857
#
#    title_title_jac_qgm_3_qgm_3  title_title_cos_dlm_dc0_dlm_dc0  \
# 0                     0.101604                         0.181902
# 1                     0.828571                         0.714286
# 2                     0.900000                         0.800000
# 3                     0.104762                         0.223607
# 4                     0.215116                         0.333333
#
#    title_title_mel  title_title_lev_dist  title_title_lev_sim  \
# 0         0.707672                  94.0             0.318841
# 1         0.916532                   2.0             0.968750
# 2         0.995833                   1.0             0.979167
# 3         0.590867                  56.0             0.125000
# 4         0.695030                 108.0             0.239437
#
#    authors_authors_jac_qgm_3_qgm_3  authors_authors_cos_dlm_dc0_dlm_dc0  \
# 0                         0.000000                             0.000000
# 1                         0.580000                             0.676123
# 2                         1.000000                             1.000000
# 3                         0.092593                             0.000000
# 4                         0.010101                             0.000000
#
#    authors_authors_mel  authors_authors_lev_dist  authors_authors_lev_sim  \
# 0             0.514006                      26.0                 0.235294
# 1             0.864320                      14.0                 0.695652
# 2             1.000000                       0.0                 1.000000
# 3             0.640811                      50.0                 0.253731
# 4             0.525752                      58.0                 0.205479
#
#    label
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0

# %%
# Instantiate the matcher to evaluate.
dt = DTMatcher(name='DecisionTree', random_state=0)

# %%
dt.fit(table=H, 
       exclude_attrs=['_id', 'l_id', 'r_id', 'label'], 
       target_attr='label')

# %%
# Convert J into a set of feature vectors using F
I = extract_feature_vecs(C, A, B,
                         '_id', 'l_id', 'r_id', 'id', 'id', 
                            nchunks=3,
                            feature_table=F,
                            
                            show_progress=False,
                            compute=False)

# %%
# help(dt.predict)

# %%
predictions = dt.predict(table=I, exclude_attrs=['_id', 'l_id', 'r_id'], 
              append=True, target_attr='predicted', inplace=False,
                        nchunks=3, scheduler=client.get, compute=False, show_progress=True)

# %%
predictions.visualize()

# %%
p = predictions.compute(get=client.get)

# %%
p.predicted.sum()
# Out:
# 32

# %%
from time import time
t = time()
x = 0
for i in range(100000):
    x = x+1
print(time()-t)
# Out:
# 0.0357918739319

# %%
from time import time
t1 = time()
p = C.compute(get=client.get)
print(time()-t1)
# Out:
# 2.10364699364

# %%
# predictions.predicted.sum()
